# %%
import tensorflow as tf
from tensorflow import keras

# plotting model
import pandas as pd
import matplotlib.pyplot as plt

# %%
# get data
(train_images, train_labels), (test_images, test_labels) = keras.datasets.mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# 11501568/11490434 [==============================] - 0s 0us/step

# %%
# setup model
model = keras.models.Sequential([
    keras.layers.Flatten(input_shape=[28,28]),
    keras.layers.Dense(128, activation=tf.nn.relu),
    keras.layers.Dense(10, activation=tf.nn.softmax)
])

model.compile(optimizer = tf.keras.optimizers.Adam(),
              loss = 'sparse_categorical_crossentropy',
              metrics=['accuracy'])

# this was the first model I tried, it had accuracy of less than 25%
# model.compile(loss='sparse_categorical_crossentropy',
#               optimizer='sgd',
#               metrics=['accuracy'])

# %%
# train model
history = model.fit(train_images, train_labels, epochs=30)
# Out:
# Epoch 1/30
# 1875/1875 [==============================] - 6s 3ms/step - loss: 2.2254 - accuracy: 0.8507
# Epoch 2/30
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3832 - accuracy: 0.9072
# Epoch 3/30
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2772 - accuracy: 0.9276
# Epoch 4/30
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2409 - accuracy: 0.9382
# Epoch 5/30
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2152 - accuracy: 0.9434
# Epoch 6/30
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1975 - accuracy: 0.9492
# Epoch 7/30
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1963 - accuracy: 0.9500
# Epoch 8/30
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1882 - accuracy: 0.9531
# Epoch 9/30
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1806 - accuracy: 0.9547
# Epoch 10/30
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.1719 - accuracy: 0.9576
# Epoch 11/30
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.1675 - accuracy: 0.9592
# Epoch 12/30
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1706 - accuracy: 0.9580
# Epoch 13/30
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1687 - accuracy: 0.9589
# Epoch 14/30
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.1619 - accuracy: 0.9606
# Epoch 15/30
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1588 - accuracy: 0.9616
# Epoch 16/30
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1557 - accuracy: 0.9627
# Epoch 17/30
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1518 - accuracy: 0.9633
# Epoch 18/30
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1514 - accuracy: 0.9642
# Epoch 19/30
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.1600 - accuracy: 0.9632
# Epoch 20/30
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1393 - accuracy: 0.9660
# Epoch 21/30
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1491 - accuracy: 0.9646
# Epoch 22/30
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1431 - accuracy: 0.9662
# Epoch 23/30
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1392 - accuracy: 0.9679
# Epoch 24/30
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1379 - accuracy: 0.9672
# Epoch 25/30
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1412 - accuracy: 0.9680
# Epoch 26/30
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.1394 - accuracy: 0.9680
# Epoch 27/30
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1377 - accuracy: 0.9681
# Epoch 28/30
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.1392 - accuracy: 0.9683
# Epoch 29/30
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1380 - accuracy: 0.9694
# Epoch 30/30
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1414 - accuracy: 0.9689

# %%
# evaluate the model
test_loss, test_acc = model.evaluate(test_images, test_labels)
print('test accuracy: ', test_acc)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.4442 - accuracy: 0.9508
# test accuracy:  0.9508000016212463

# %%
# make predictions
predictions = model.predict(test_images)

# %%
# plots
pd.DataFrame(history.history).plot(figsize=(8,5))
plt.grid(True)
plt.gca().set_ylim(0, 1)
plt.show()
